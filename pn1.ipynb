# %%
import pandas as pd
std_data=[(1,"varun",30,"chandigarh"),
           (2,"gudu",40,"odisha"),
           (3,"biswa",22,"bengal")]
df=pd.DataFrame(std_data,columns=["stud_id","name","age","place"])
df
